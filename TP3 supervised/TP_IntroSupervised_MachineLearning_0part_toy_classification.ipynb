# %% [markdown]
# **Toy examples**
#
# In this part of the practical session, you will play with some toy data to better understand the classification algorithms seen this morning.
#
# Please answer all questions
#
# **Deadline**: Upload this notebook, the one about Emotion Recognition and the answers to the theoretical questions to E-Campus. Please verify the exact deadline on E-Campus.

# %% [markdown]
# Let's first load the needed packages.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt  # for plots
from matplotlib.colors import ListedColormap
from matplotlib import rc

import seaborn as sns
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
import time

# %matplotlib inline
np.random.seed(seed=666)
plt.style.use("dark_background")

# %% [markdown]
# Here, we define some functions useful for generating and plotting the data

# %%
def gaussian_data_generation(n, mean, cov, noise_std):
   # create data which follows a multivariate Gaussian distribution
   # a white (Gaussian) noise is then added to the data
    
    assert cov.shape[0] == cov.shape[1], "Please use only square covariance matrix"    
    assert len(mean) == cov.shape[0], "the dimension of the mean should be equal to the dimension of the covariance matrix"
    
    X = np.random.multivariate_normal(mean, cov, n) # actual data
    X = X + np.random.multivariate_normal(np.zeros(len(mean)), noise_std ** 2 *np.eye(len(mean)), n)  # we add white noise to the data     
   
    return X

def frontiere(f, X, y, step=50):
    # decision boundary of classifier f
    # construct cmap

    min_tot = np.min(X)
    max_tot = np.max(X)
    delta = (max_tot - min_tot) / step
    xx, yy = np.meshgrid(np.arange(min_tot, max_tot, delta),
                         np.arange(min_tot, max_tot, delta))
    z = np.array([f(vec) for vec in np.c_[xx.ravel(), yy.ravel()]])
    z = z.reshape(xx.shape)
    labels = np.unique(z)
    color_blind_list = sns.color_palette("colorblind", labels.shape[0])
    sns.set_palette(color_blind_list)
    my_cmap = ListedColormap(color_blind_list)
    plt.imshow(z, origin='lower', extent=[min_tot, max_tot, min_tot, max_tot],
               interpolation="mitchell", alpha=0.80, cmap=my_cmap)

    ax = plt.gca()
    cbar = plt.colorbar(ticks=labels)
    cbar.ax.set_yticklabels(labels)

    k = np.unique(y).shape[0]
    color_blind_list = sns.color_palette("colorblind", k)
    for i, label in enumerate(y):
        plt.scatter(X[i, 0], X[i, 1], c=[color_blind_list[int(y[i])]],
                    s=80, marker=symlist[int(label)])
    plt.ylim([min_tot, max_tot])
    plt.xlim([min_tot, max_tot])
    ax.get_yaxis().set_ticks([])
    ax.get_xaxis().set_ticks([])
    
def class_int_round(z, n_class):
    # rounding needed to go from real to integer values 
    output = np.round(z).astype(int)
    if isinstance(z, np.ndarray):
        j = z < 0
        output[j] = 0
        k = z > n_class - 1
        output[k] = n_class - 1
    else:
        if output < 0:
            output = 0
        else:
            if output > n_class - 1:
                output = n_class - 1
    return output

# %% [markdown]
# The next function is the one you will use to crete the toy data. You can choose among three scenarios: 2, 3 or 4 classes. Each class is composed of 2D points sampled from a multivariate Gaussian distribution. You can choose the number of samples, average and covariance matrix for each class.

# %%
def generate_scenario(n_classes=3):
    
    if n_classes == 2:
        # Example with 2 classes
        n_0=80
        mean_0 = [0, 0]        
        cov_0 = np.array([[1, 0.1], [0.1, 0.9]])
        X_0=gaussian_data_generation(n_0, mean_0, cov_0, 0.1)
        y_0=np.zeros(n_0)
        
        n_1=80
        mean_1 = [3, 2]
        cov_1 = np.array([[0.1, 0], [0, 0.5]])
        X_1=gaussian_data_generation(n_1, mean_1, cov_1, 0.1)
        y_1=np.ones(n_1)
        
        X=np.concatenate((X_0,X_1))
        y=np.concatenate((y_0,y_1))
        
    elif n_classes == 3:
        # Example with 3 classes
        n_0=80
        mean_0 = [0, 0]        
        cov_0 = np.array([[1, 0.1], [0.1, 0.9]])
        X_0=gaussian_data_generation(n_0, mean_0, cov_0, 0.1)
        y_0=np.zeros(n_0)
        
        n_1=80
        mean_1 = [2, 2]
        cov_1 = np.array([[0.1, 0], [0, 0.5]])
        X_1=gaussian_data_generation(n_1, mean_1, cov_1, 0.1)
        y_1=np.ones(n_1)
        
        n_2=80
        mean_2 = [3, 3]
        cov_2 = np.array([[0.5, 0.1], [0.1, 1]])
        X_2=gaussian_data_generation(n_2, mean_2, cov_2, 0.1)
        y_2=2*np.ones(n_2)
        
        X=np.concatenate((X_0,X_1,X_2))
        y=np.concatenate((y_0,y_1,y_2))
    elif n_classes == 4:
        # Example with 4 classes
        n_0=80
        mean_0 = [0, 0]        
        cov_0 = np.array([[1, 0.1], [0.1, 0.9]])
        X_0=gaussian_data_generation(n_0, mean_0, cov_0, 0.1)
        y_0=np.zeros(n_0)
        
        n_1=80
        mean_1 = [3, 3]
        cov_1 = np.array([[0.1, 0], [0, 0.5]])
        X_1=gaussian_data_generation(n_1, mean_1, cov_1, 0.1)
        y_1=np.ones(n_1)
        
        n_2=80
        mean_2 = [0, 3]
        cov_2 = np.array([[0.5, 0.1], [0.1, 1]])
        X_2=gaussian_data_generation(n_2, mean_2, cov_2, 0.1)
        y_2=2*np.ones(n_2)
        
        n_3=80
        mean_3 = [3, 0]
        cov_3 = np.array([[0.9, 0.15], [0.15, 0.8]])
        X_3=gaussian_data_generation(n_3, mean_3, cov_3, 0.1)
        y_3=3*np.ones(n_3)
        
        X=np.concatenate((X_0,X_1,X_2,X_3))
        y=np.concatenate((y_0,y_1,y_2,y_3))  

    return X, y

# %% [markdown]
# Let's choose a scenario and generate some data

# %%
######## PARAMETER TO CHOOSE THE SCENARIO (number of classes) #######
n_classes=4
#####################################################################

X, y = generate_scenario(n_classes)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# Let's plot the data

# %%
fig1 = plt.figure(figsize=(6, 6))
ax = plt.gca()
min_tot = np.min(X)
max_tot = np.max(X)
symlist = ['o', 'p', '*', 's', '+', 'x', 'D', 'v', '-', '^']
k = np.unique(y).shape[0]
color_blind_list = sns.color_palette("colorblind", k)
for i, label in enumerate(y):
    plt.scatter(X[i, 0], X[i, 1], c=[color_blind_list[int(y[i])]],
                s=80, marker=symlist[int(label)])
#ax.get_yaxis().set_ticks([])
#ax.get_xaxis().set_ticks([])

# %% [markdown]
# As first classifier, we can use a simple linear regression where we  transform in integers the predictions.
#
#  **Question**: look at the function 'class_int_round'. Explain what it does.
#
#  **Answer**: Cette fonction permet de passer des valeurs réelles données par la régression aux classes correspondantes caractérisées par un entier. On va donc considérer que la classe est la valeur arrondi de la valeur prédite. Dans les cas limites (valeur négative ou arrondi supérieur au nombre de classe), on ramène à la classe la plus proche.

# %%
##############################################################################
# Naive linear regression on raw observations
##############################################################################

resolution_param = 50  # 500 for nice plotting, 50 for fast version
regr = LinearRegression()
regr.fit(X_train, y_train)
y_pred_test = class_int_round(regr.predict(X_test), n_classes)

# Plotting part
fig0 = plt.figure(figsize=(12, 8))
title = "Left out accuracy (regression w./o. dummy variables)" + \
        ": {:.2f}".format(accuracy_score(y_test, y_pred_test))
plt.title(title)

def f(xx):
    """Classifier"""
    return class_int_round(regr.predict(xx.reshape(1, -1)), n_classes)
frontiere(f, X, y, step=resolution_param)

plt.show()

# %% [markdown]
# Instead of using this simple strategy, we can also use a *OneHotEncoder*.
#
# **Question**: Do you see any difference in the resulting decision boundaries ? Which is the best strategy in your opinion ? Why ?
#
# **Answer**: Avec cette méthode on peut avoir des frontières en 'plusieurs morceaux' dans le sens où se ne sont plus uniquement que des droites. Dans une logique de classification cette méthode est meilleure dans le sens où la prédiction s'effectue selon la probabilité d'être dans une classe. L'encodage permet de considérer que toutes les classes sont à la même distance. Empiriquement on voit que l'on obtient des scores de précision équivalent ou largement supérieur à la régression naïve.

# %%
##############################################################################
# Naive linear regression on dummy variables (OneHotEncoder)
##############################################################################
resolution_param = 150  
enc = OneHotEncoder(categories='auto')
enc.fit(y_train.reshape(-1, 1))
Y = enc.transform(y_train.reshape(-1, 1)).toarray()
regr_multi = LinearRegression()
regr_multi.fit(X_train, Y)
proba_vector_test = regr_multi.predict(X_test)
y_pred_test = class_int_round(regr.predict(X_test), n_classes)

# performance evaluation on new dataset
y_pred_test = np.argmax(proba_vector_test, axis=1)
title = "Left out accuracy (regression with OneHotEncoder)" + \
        ": {:.2f}".format(accuracy_score(y_test, y_pred_test))

# Plotting part
fig1 = plt.figure(figsize=(12, 8))
plt.title(title)


def f(xx):
    """Classifier"""
    return np.argmax(regr_multi.predict(xx.reshape(1, -1)))
frontiere(f, X, y, step=resolution_param)

plt.show()

# %% [markdown]
# Let's use the other strategies seen this morning.

# %%
##############################################################################
# Logistic regression
##############################################################################
resolution_param = 150  
clf = LogisticRegression(solver='lbfgs',multi_class='ovr') # you can also try multi_class='multinomial', 
clf.fit(X_train, y_train)
y_logit_test = clf.predict(X_test)
title = "Left out accuracy (logistic regression) " + \
        ": {:.2f}".format(accuracy_score(y_test, y_logit_test))
fig2 = plt.figure(figsize=(12, 8))
plt.title(title)


def f(xx):
    """Classifier"""
    return int(clf.predict(xx.reshape(1, -1)))
frontiere(f, X, y, step=resolution_param)

plt.show()

# %%
##############################################################################
# LDA
##############################################################################
resolution_param = 150  
clf_LDA = LinearDiscriminantAnalysis()
clf_LDA.fit(X_train, y_train)
y_LDA_test = clf_LDA.predict(X_test)

title = "Left out accuracy (LDA) " + \
        ": {:.2f}".format(accuracy_score(y_test, y_LDA_test))
fig2 = plt.figure(figsize=(12, 8))
plt.title(title)


def f(xx):
    """Classifier"""
    return int(clf_LDA.predict(xx.reshape(1, -1)))
frontiere(f, X, y, step=resolution_param)

plt.show()

# %%
##############################################################################
# QDA
##############################################################################
resolution_param = 150 
clf_QDA = QuadraticDiscriminantAnalysis()
clf_QDA.fit(X_train, y_train)
y_QDA_test = clf_QDA.predict(X_test)
title = "Left out accuracy (QDA) " + \
        ": {:.2f}".format(accuracy_score(y_test, y_QDA_test))
fig2 = plt.figure(figsize=(12, 8))
plt.title(title)


def f(xx):
    """Classifier"""
    return int(clf_QDA.predict(xx.reshape(1, -1)))
frontiere(f, X, y, step=resolution_param)

plt.show()

# %%
##############################################################################
# Naive Bayes 
##############################################################################
resolution_param = 150  
clf_GNB = GaussianNB()
clf_GNB.fit(X_train, y_train)

y_test_GNB = clf_GNB.predict(X_test)

title = "Left out accuracy (GNB) " + \
        ": {:.2f}".format(accuracy_score(y_test, y_test_GNB))
fig2 = plt.figure(figsize=(12, 8))
plt.title(title)


def f(xx):
    """Classifier"""
    return int(clf_GNB.predict(xx.reshape(1, -1)))
frontiere(f, X, y, step=resolution_param)

plt.show()

# %%
##############################################################################
# KNN
##############################################################################
resolution_param = 150  
clf_KNN = KNeighborsClassifier()
clf_KNN.n_neighbors=5

clf_KNN.fit(X_train, y_train)
y_KNN_test = clf_KNN.predict(X_test)

title = "Left out accuracy (KNN) " + \
        ": {:.2f}".format(accuracy_score(y_test, y_KNN_test))
fig2 = plt.figure(figsize=(12, 8))
plt.title(title)

def f(xx):
    """Classifier"""
    return int(clf_KNN.predict(xx.reshape(1, -1)))
frontiere(f, X, y, step=resolution_param)

plt.show()

# %% [markdown]
# **Questions**:
#
#
# *   Describe the decision boundaries of the methods. Are all linear ?
# *   Using the following code, compare the computational time and the test accuracy of the different methods in the three scenarios. Comment the results.
# * (Optional) If you change the number of samples per class (both training and test), do the results vary ?
#
# **Answer**:
#
# - Logistic regression, est considéré comme linéaire car le résultat ne va dépendre que de la somme, éventuellement pondérée, des paramètres. Celà est du au fait que l'on travail avec le log de la probabilité qui est elle linéaire. On va donc obtenir des régions de décision données par des morceaux de droite.
#
# - Linear Discriminant analysis, ce modèle est aussi linéaire (c'est dans le nom) et donc on aura aussi des régions de décisions données par des morceaux de droite.
#
# - Quadratic discriminant analysis, ce modèle est non linéaire (il est quadratique), donc les régions de décisions sont données par des intersections de paraboles.
#
# - Naives Bayes, comme le QDA mais avec des paraboles différentes
#
# - KNN, ce modèle est aussi non linéaire et les régions de décision n'ont pas de structures particulières et dépendent du nombre de voisins pris en compte.
#
#
# On constate que le modèle Bayésien naïf est celui qui a en moyenne les meilleures performances pour un temps de calcul parmi les plus faibles. Néanmoins celà est du au fait que les matrices de covariances des échantillons sont presque négatives. Si ce n'est pas le cas alors la QDA sera plus précise mais on aura un temps de calcul plus important (même s'il restera très faible).

# %%
time_tab = np.zeros((3,7))
acc_tab = np.zeros((3,7))

######## PARAMETER TO CHOOSE THE SCENARIO (number of classes) #######
for n_classes in range(3):
#####################################################################
    print("n_classes=",n_classes+2)
    
    X, y = generate_scenario(n_classes+2)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

    # example using KNN
    time_start = time.perf_counter()
    clf_KNN.fit(X_train, y_train)
    y_test_pred = clf_KNN.predict(X_test)
    time_tab[n_classes,0] = (time.perf_counter() - time_start)
    acc_tab[n_classes,0] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,0], 's ; Test accuracy KNN', "%.2f" %acc_tab[n_classes,0])

    # example using Naive Bayes
    time_start = time.perf_counter()
    clf_GNB.fit(X_train, y_train)
    y_test_pred = clf_GNB.predict(X_test)
    time_tab[n_classes,1] = (time.perf_counter() - time_start)
    acc_tab[n_classes,1] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,1], 's ; Test accuracy GNB', "%.2f" %acc_tab[n_classes,1])

    # example using QDA
    time_start = time.perf_counter()
    clf_QDA.fit(X_train, y_train)
    y_test_pred = clf_QDA.predict(X_test)
    time_tab[n_classes,2] = (time.perf_counter() - time_start)
    acc_tab[n_classes,2] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,2], 's ; Test accuracy QDA', "%.2f" %acc_tab[n_classes,2])

    # example using LDA
    time_start = time.perf_counter()
    clf_LDA.fit(X_train, y_train)
    y_test_pred = clf_LDA.predict(X_test)
    time_tab[n_classes,3] = (time.perf_counter() - time_start)
    acc_tab[n_classes,3] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,3], 's ; Test accuracy LDA', "%.2f" %acc_tab[n_classes,3])

    # example using Logistic
    time_start = time.perf_counter()
    clf.fit(X_train, y_train)
    y_test_pred = clf.predict(X_test)
    time_tab[n_classes,4] = (time.perf_counter() - time_start)
    acc_tab[n_classes,4] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,4], 's ; Test accuracy Logistic', "%.2f" %acc_tab[n_classes,4])

    # example using Naive regression w/ OneHot
    time_start = time.perf_counter()
    enc.fit(y_train.reshape(-1, 1))
    Y = enc.transform(y_train.reshape(-1, 1)).toarray()
    regr_multi = LinearRegression()
    regr_multi.fit(X_train, Y)
    proba_vector_test = regr_multi.predict(X_test)
    y_test_pred = np.argmax(proba_vector_test, axis=1)
    time_tab[n_classes,5] = (time.perf_counter() - time_start)
    acc_tab[n_classes,5] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,5], 's ; Test accuracy OneHot', "%.2f" %acc_tab[n_classes,5])

    # example using Naive regression
    time_start = time.perf_counter()
    regr.fit(X_train, y_train)
    y_test_pred =  class_int_round(regr.predict(X_test), n_classes)
    time_tab[n_classes,6] = (time.perf_counter() - time_start)
    acc_tab[n_classes,6] = accuracy_score(y_test, y_test_pred)
    print('Computational time:', "%.4f" %time_tab[n_classes,6], 's ; Test accuracy naive OLS', "%.2f" %acc_tab[n_classes,6])
# Out:
# n_classes= 2
# Computational time: 0.0017 s ; Test accuracy KNN 1.00
# Computational time: 0.0007 s ; Test accuracy GNB 1.00
# Computational time: 0.0014 s ; Test accuracy QDA 1.00
# Computational time: 0.0015 s ; Test accuracy LDA 0.97
# Computational time: 0.0029 s ; Test accuracy Logistic 1.00
# Computational time: 0.0011 s ; Test accuracy OneHot 0.97
# Computational time: 0.0007 s ; Test accuracy naive OLS 0.00
# n_classes= 3
# Computational time: 0.0020 s ; Test accuracy KNN 0.87
# Computational time: 0.0010 s ; Test accuracy GNB 0.85
# Computational time: 0.0010 s ; Test accuracy QDA 0.85
# Computational time: 0.0012 s ; Test accuracy LDA 0.82
# Computational time: 0.0105 s ; Test accuracy Logistic 0.83
# Computational time: 0.0024 s ; Test accuracy OneHot 0.70
# Computational time: 0.0004 s ; Test accuracy naive OLS 0.30
# n_classes= 4
# Computational time: 0.0024 s ; Test accuracy KNN 0.89
# Computational time: 0.0013 s ; Test accuracy GNB 0.94
# Computational time: 0.0011 s ; Test accuracy QDA 0.93
# Computational time: 0.0010 s ; Test accuracy LDA 0.89
# Computational time: 0.0098 s ; Test accuracy Logistic 0.89
# Computational time: 0.0012 s ; Test accuracy OneHot 0.89
# Computational time: 0.0003 s ; Test accuracy naive OLS 0.23

# %%
classifier = ['KNN','GNB','QDA','LDA','Log','OneHot']
for n_classes,acc in enumerate(acc_tab):
    plt.subplot(1,2,1)
    plt.bar(classifier,acc[:-1])
    plt.title("Accuracy with n_classes = "+str(n_classes+2))
    plt.ylim(np.min(acc[:-1]-0.02))
    
    plt.subplot(1,2,2)
    plt.bar(classifier,time_tab[n_classes,:-1])
    plt.title("Computing time")
    plt.tight_layout()
    plt.show()
